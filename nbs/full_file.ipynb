# %%
import graphlab as gl
# Out:
# A newer version of GraphLab Create (v1.6.1) is available! Your current version is v1.2.1.
# You can use pip to upgrade the graphlab-create package. For more information see http://graphlab.com/products/create/upgrade.

# %%
df.column_names()
# Out:
# ['Entity',
#  'Relation',
#  'Value',
#  'Iteration of Candidacy',
#  'Candidate Probability',
#  'Source',
#  'Entity literalStrings',
#  'Value literalStrings',
#  'Best Entity literalString',
#  'Best Value literalString',
#  'Categories for Entity',
#  'Categories for Value',
#  'Candidate Source',
#  'type']

# %%
df = gl.SFrame.read_csv('/Users/gwulfs/Downloads/NELL.08m.950.cesv.csv', nrows=10000000, delimiter='\t')
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-39293 - Server binary: /Library/Python/2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1447553200.log
# [INFO] GraphLab Server Version: 1.2.1
# PROGRESS: Finished parsing file /Users/gwulfs/Downloads/NELL.08m.950.cesv.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.30674 secs.
# Could not detect types. Using str for each column.
# PROGRESS: Unable to parse line "concept:ceo:__________option___________option_dakota_mack_value___	candidate:generalizations	concept:ceo	[545]	[0.5]	%28null%29	"{">[...]</option>         <option Dakota Mack value="}" 		{">[...]</option>         <option Dakota Mack value="}			 concept:person	%5BSEAL-Iter%3A545-2012%2F04%2F02-23%3A24%3A52-%3Ctoken%3D__________option___________option_dakota_mack_value___%2Cceo%3E-From%3ACategory%3Aceo-using-KB+http%3A%2F%2Fjimstefani.blogspot.com%2F2006_09_10_archive.html+%7D%5D"
# PROGRESS: Unable to parse line "concept:musicinstrument:__________a__br__rote	candidate:generalizations	concept:musicinstrument	[604]	[0.5]	%28null%29	"{">[...]</a><br> ROTE" 		{">[...]</a><br> ROTE			 concept:item concept:visualizableobject	%5BSEAL-Iter%3A604-2012%2F06%2F28-07%3A36%3A57-%3Ctoken%3D__________a__br__rote%2Cmusicinstrument%3E-From%3ACategory%3Amusicinstrument-using-KB+http%3A%2F%2Fwww.istitutomascagni.it%2F%3Fp%3Dnull%5D"
# PROGRESS: Unable to parse line "concept:country:____university_of___________central_asia	candidate:generalizations	concept:country	[527]	[0.75]	%28null%29	"{,  University of  [...],  }Central Asia" 		{,  University of  [...],  }Central Asia			 concept:geopoliticallocation concept:geopoliticalorganization concept:geolocatablething	%5BSEAL-Iter%3A527-2012%2F03%2F08-16%3A43%3A16-%3Ctoken%3D____university_of___________central_asia%2Ccountry%3E-From%3ACategory%3Acountry-using-KB+http%3A%2F%2Fen.wikipedia.org%2Fwiki%2FMiddle_Asia+http%3A%2F%2Fen.wikipedia.org%2Fwiki%2FCentral_Asian%5D"
# PROGRESS: Unable to parse line "concept:governmentorganization:__index_php__class__main_body________tickets__a___td___tr__tr__td__a_rapids__police_departmenttarget___self_	candidate:generalizations	concept:governmentorganization	[587]	[0.5]	%28null%29	"{/index.php" class="main-body">[...] Tickets</a></td></tr><tr><td><a rapids  police departmenttarget="_self"" 		{/index.php" class="main-body">[...] Tickets</a></td></tr><tr><td><a rapids  police departmenttarget="_self"			 concept:politicsgroup	%5BSEAL-Iter%3A587-2012%2F06%2F05-14%3A58%3A14-%3Ctoken%3D__index_php__class__main_body________tickets__a___td___tr__tr__td__a_rapids__police_departmenttarget___self_%2Cgovernmentorganization%3E-From%3ACategory%3Agovernmentorganization-using-KB+http%3A%2F%2Fwww.policepatch.biz%2Findex.html%5D"
# PROGRESS: Read 968896 lines. Lines per second: 140421
# PROGRESS: 44 lines failed to parse correctly
# PROGRESS: Finished parsing file /Users/gwulfs/Downloads/NELL.08m.950.cesv.csv
# PROGRESS: Parsing completed. Parsed 1000000 lines in 7.05796 secs.

# %%
df['Entity'][0][8:].split(':')[0]
df['type'] = df['Entity'].apply(lambda x: x.split()[0][8:].split(':')[0])
df = df[df['type'] == 'disease']

# %%
df.head(1)
# Out:
# Columns:
# 	Entity	str
# 	Relation	str
# 	Value	str
# 	Iteration of Candidacy	str
# 	Candidate Probability	str
# 	Source	str
# 	Entity literalStrings	str
# 	Value literalStrings	str
# 	Best Entity literalString	str
# 	Best Value literalString	str
# 	Categories for Entity	str
# 	Categories for Value	str
# 	Candidate Source	str
#
# Rows: 1
#
# Data:
# +----------------------------+---------------------------+----------------+
# |           Entity           |          Relation         |     Value      |
# +----------------------------+---------------------------+----------------+
# | concept:recipe:pasta_quick | candidate:generalizations | concept:recipe |
# +----------------------------+---------------------------+----------------+
# +------------------------+-----------------------+------------+-----------------------+
# | Iteration of Candidacy | Candidate Probability |   Source   | Entity literalStrings |
# +------------------------+-----------------------+------------+-----------------------+
# |        [221]\t         |        [0.5]\t        | %28null%29 |      Pasta Quick      |
# +------------------------+-----------------------+------------+-----------------------+
# +----------------------+---------------------------+--------------------------+-----------------------+
# | Value literalStrings | Best Entity literalString | Best Value literalString | Categories for Entity |
# +----------------------+---------------------------+--------------------------+-----------------------+
# |                      |        Pasta Quick        |                          |                       |
# +----------------------+---------------------------+--------------------------+-----------------------+
# +-----------------------+--------------------------------+
# |  Categories for Value |        Candidate Source        |
# +-----------------------+--------------------------------+
# | concept:abstractthing | %5BSEAL-Iter%3A221-2011%2F ... |
# +-----------------------+--------------------------------+
# [1 rows x 13 columns]

# %%
len(df)
# Out:
# 3999

# %%
df.head()
# Out:
# Columns:
# 	Entity	str
# 	Relation	str
# 	Value	str
# 	Iteration of Candidacy	str
# 	Candidate Probability	str
# 	Source	str
# 	Entity literalStrings	str
# 	Value literalStrings	str
# 	Best Entity literalString	str
# 	Best Value literalString	str
# 	Categories for Entity	str
# 	Categories for Value	str
# 	Candidate Source	str
# 	type	str
#
# Rows: 10
#
# Data:
# +--------------------------------+--------------------------------+
# |             Entity             |            Relation            |
# +--------------------------------+--------------------------------+
# | concept:disease:n3_methylg ... |   candidate:generalizations    |
# |      concept:disease:ucds      |   candidate:generalizations    |
# | concept:disease:congenital ... |   candidate:generalizations    |
# | concept:disease:constant_p ... |   candidate:generalizations    |
# |  concept:disease:cancer_plans  |   candidate:generalizations    |
# | concept:disease:vocal_cord ... |   candidate:generalizations    |
# | concept:disease:psychogeni ... | candidate:concept:haswikip ... |
# | concept:disease:psychogeni ... |   candidate:generalizations    |
# | concept:disease:over_65_ye ... |   candidate:generalizations    |
# | concept:disease:primary_he ... |   candidate:generalizations    |
# +--------------------------------+--------------------------------+
# +--------------------------------+------------------------+
# |             Value              | Iteration of Candidacy |
# +--------------------------------+------------------------+
# |        concept:disease         |        [222]\t         |
# |        concept:disease         |        [772]\t         |
# |        concept:disease         |        [574]\t         |
# |        concept:disease         |        [238]\t         |
# |        concept:disease         |        [668]\t         |
# |        concept:disease         |        [544]\t         |
# | http://en.wikipedia.org/wi ... |        [621]\t         |
# |        concept:disease         |        [583]\t         |
# |        concept:disease         |         [41]\t         |
# |        concept:disease         |         [51]\t         |
# +--------------------------------+------------------------+
# +------------------------+--------------------------------+
# | Candidate Probability  |             Source             |
# +------------------------+--------------------------------+
# |        [0.5]\t         |           %28null%29           |
# | [0.8288469466041748]\t |           %28null%29           |
# |        [0.5]\t         |           %28null%29           |
# |        [0.5]\t         |           %28null%29           |
# | [0.561440415913448]\t  |           %28null%29           |
# |        [0.5]\t         |           %28null%29           |
# |        [0.95]\t        | MBL-Iter%3A710-2013%2F03%2 ... |
# |        [0.75]\t        |           %28null%29           |
# |        [0.5]\t         |           %28null%29           |
# |        [0.5]\t         |           %28null%29           |
# +------------------------+--------------------------------+
# +--------------------------------+--------------------------------+
# |     Entity literalStrings      |      Value literalStrings      |
# +--------------------------------+--------------------------------+
# | 3 methylglutaconyl coa hyd ... |                                |
# |          UCDs "ucds"           |                                |
# | Congenital thickening of t ... |                                |
# |        constant pyuria         |                                |
# |          cancer plans          |                                |
# |       Vocal cord paresis       |                                |
# |      Psychogenic pruritus      | http://en.wikipedia.org/wi ... |
# |      Psychogenic pruritus      |                                |
# |      over-65-years-of-age      |                                |
# | primary herpes infection t ... |                                |
# +--------------------------------+--------------------------------+
# +--------------------------------+--------------------------------+-----------------------+
# |   Best Entity literalString    |    Best Value literalString    | Categories for Entity |
# +--------------------------------+--------------------------------+-----------------------+
# | 3 methylglutaconyl coa hyd ... |                                |                       |
# |              UCDs              |                                |                       |
# | Congenital thickening of t ... |                                |                       |
# |        constant pyuria         |                                |                       |
# |          cancer plans          |                                |                       |
# |       Vocal cord paresis       |                                |                       |
# |      Psychogenic pruritus      | http://en.wikipedia.org/wi ... |                       |
# |      Psychogenic pruritus      |                                |                       |
# |      over-65-years-of-age      |                                |                       |
# | primary herpes infection t ... |                                |                       |
# +--------------------------------+--------------------------------+-----------------------+
# +--------------------------------+--------------------------------+---------+
# |      Categories for Value      |        Candidate Source        |   type  |
# +--------------------------------+--------------------------------+---------+
# | concept:physiologicalcondition | %5BSEAL-Iter%3A222-2011%2F ... | disease |
# | concept:physiologicalcondition | %5BCPL-Iter%3A772-2013%2F0 ... | disease |
# | concept:physiologicalcondition | %5BSEAL-Iter%3A574-2012%2F ... | disease |
# | concept:physiologicalcondition | %5BSEAL-Iter%3A238-2011%2F ... | disease |
# | concept:physiologicalcondition | %5BCPL-Iter%3A668-2012%2F1 ... | disease |
# | concept:physiologicalcondition | %5BSEAL-Iter%3A544-2012%2F ... | disease |
# |                                | %5BAliasMatcher-Iter%3A621 ... | disease |
# | concept:physiologicalcondition | %5BSEAL-Iter%3A583-2012%2F ... | disease |
# | concept:physiologicalcondition | %5BSEAL-Iter%3A41-2010-02- ... | disease |
# | concept:physiologicalcondition | %5BSEAL-Iter%3A51-2010-02- ... | disease |
# +--------------------------------+--------------------------------+---------+
# [10 rows x 14 columns]

# %%
df = df[df['Best Entity literalString'] != 'Type']
df = df[df['Best Entity literalString'] != 'FORUMS']

# %%
df['Best Entity literalString']
